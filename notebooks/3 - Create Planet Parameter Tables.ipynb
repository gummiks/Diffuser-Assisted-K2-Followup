# %% [markdown]
# # Planet parameter tables for K2-28b and K2-100b
# - Read in the planet parameters from the MCMC fits and create a table containing the information for K2, Ground, Joint fit for K2 and Joint fit for ground

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../src/")

#Read in the K2, Ground, Joint fit for K2 and Joint fit for Ground data for K2-28b and K2-100b
df_ground_k2_28b = pd.read_csv("../data/k2_28b/k2-28b_ground_for_latex_table_final.csv",sep=",",header=0)
df_k2_k2_28b = pd.read_csv("../data/k2_28b/k2-28b_k2_for_latex_table_final.csv",sep=",",header=0)
df_jointground_k2_28b=pd.read_csv("../data/k2_28b/k2-28b_jointground_for_latex_table_final.csv",sep=",",header=0)
df_jointk2_k2_28b=pd.read_csv("../data/k2_28b/k2-28b_jointk2_for_latex_table_final.csv",sep=",",header=0)

df_ground_k2_100b = pd.read_csv("../data/k2_100b/k2-100b_grounddata_for_latex_table_final.csv",sep=",",header=0)
df_k2_k2_100b = pd.read_csv("../data/k2_100b/k2-100b_k2_for_latex_table_final.csv",sep=",",header=0)
df_jointground_k2_100b=pd.read_csv("../data/k2_100b/k2-100b_jointground_for_latex_table_final.csv",sep=",",header=0)
df_jointk2_k2_100b=pd.read_csv("../data/k2_100b/k2-100b_jointk2_for_latex_table_final.csv",sep=",",header=0)

# %%
#Create planet parameter table for K2-28b
k2_28b_table=pd.DataFrame({'Labels': df_ground_k2_28b['Labels'],
                            'Description':df_ground_k2_28b['Description'],
                            'K2': df_k2_k2_28b['K2'],
                            'Ground':df_ground_k2_28b['Ground'],
                            'Joint fit for Ground':df_jointground_k2_28b['Ground'],
                            'Joint fit for K2':df_jointk2_k2_28b['K2']})
k2_28b_table=k2_28b_table[['Labels','Description','K2','Ground','Joint fit for Ground','Joint fit for K2']]

#Create planet parameter table for K2-100b
k2_100b_table=pd.DataFrame({'Labels': df_ground_k2_100b['Labels'],
                            'Description':df_ground_k2_100b['Description'],
                            'K2': df_k2_k2_100b['K2'],
                            'Ground':df_ground_k2_100b['Ground'],
                            'Joint fit for Ground':df_jointground_k2_100b['Ground'],
                            'Joint fit for K2':df_jointk2_k2_100b['K2']})
k2_100b_table=k2_100b_table[['Labels','Description','K2','Ground','Joint fit for Ground','Joint fit for K2']]

# %%
# TODO: add to paper. finished
k2_28b_table
# Out:
#                                                Labels  \
# 0                      $T_{0}$ $(\mathrm{BJD_{TDB}})$
# 1                                          $P$ (days)
# 2                                           $R_p/R_*$
# 3                                    $R_p (R_\oplus)$
# 4                                         $R_p (R_J)$
# 5                                            $\delta$
# 6                                             $a/R_*$
# 7                                            $a$ (AU)
# 8   $\rho_{\mathrm{*,transit}}$ ($\mathrm{g/cm^{3}}$)
# 9                                    $i$ $(^{\circ})$
# 10                                                $b$
# 11                                                $e$
# 12                              $\omega$ ($^{\circ}$)
# 13                              $T_{\mathrm{eq}}$ (K)
# 14                                 $S$ ($S_{\oplus}$)
# 15                                    $T_{14}$ (days)
# 16                                      $\tau$ (days)
# 17                     $T_{S}$ $(\mathrm{BJD_{TDB}})$
#
#                              Description  \
# 0                       Transit Midpoint
# 1                         Orbital period
# 2                           Radius ratio
# 3                          Planet radius
# 4                          Planet radius
# 5                          Transit depth
# 6              Normalized orbital radius
# 7                        Semi-major axis
# 8                        Density of star
# 9                    Transit inclination
# 10                      Impact parameter
# 11                          Eccentricity
# 12                Argument of periastron
# 13  Equilibrium temp. (assuming $a=0.3$)
# 14                       Insolation Flux
# 15                      Transit duration
# 16               Ingress/egress duration
# 17             Time of secondary eclipse
#
#                                        K2  \
# 0   $2456977.98986_{-0.00027}^{+0.00026}$
# 1        $2.260443_{-0.00002}^{+0.00002}$
# 2            $0.0763_{-0.0027}^{+0.0056}$
# 3                  $2.42_{-0.25}^{+0.27}$
# 4               $0.216_{-0.023}^{+0.025}$
# 5         $0.00583_{-0.00040}^{+0.00089}$
# 6                    $16.9_{-3.8}^{+2.7}$
# 7            $0.0222_{-0.0050}^{+0.0044}$
# 8                   $17.9_{-9.6}^{+10.0}$
# 9                    $88.2_{-1.5}^{+1.3}$
# 10                 $0.54_{-0.34}^{+0.22}$
# 11                    $0.0_{-0.0}^{+0.0}$
# 12                    $0.0_{-0.0}^{+0.0}$
# 13                $387.0_{-28.0}^{+53.0}$
# 14                  $15.6_{-4.0}^{+10.0}$
# 15           $0.0398_{-0.0012}^{+0.0026}$
# 16           $0.0039_{-0.0011}^{+0.0032}$
# 17  $2456979.12008_{-0.00026}^{+0.00025}$
#
#                                    Ground  \
# 0   $2457931.89781_{-0.00033}^{+0.00033}$
# 1           $2.26044_{-0.0001}^{+0.0001}$
# 2            $0.0785_{-0.0030}^{+0.0029}$
# 3                  $2.47_{-0.26}^{+0.27}$
# 4                $0.22_{-0.023}^{+0.024}$
# 5         $0.00617_{-0.00046}^{+0.00047}$
# 6                    $14.1_{-1.7}^{+2.2}$
# 7            $0.0188_{-0.0030}^{+0.0036}$
# 8                    $10.3_{-3.4}^{+5.7}$
# 9                 $87.11_{-0.75}^{+0.85}$
# 10               $0.709_{-0.13}^{+0.075}$
# 11                    $0.0_{-0.0}^{+0.0}$
# 12                    $0.0_{-0.0}^{+0.0}$
# 13                $424.0_{-31.0}^{+30.0}$
# 14                   $22.4_{-5.9}^{+7.2}$
# 15           $0.0417_{-0.0017}^{+0.0021}$
# 16           $0.0057_{-0.0016}^{+0.0020}$
# 17  $2457933.02803_{-0.00034}^{+0.00034}$
#
#                      Joint fit for Ground  \
# 0   $2457931.89779_{-0.00031}^{+0.00032}$
# 1   $2.2604455_{-0.0000009}^{+0.0000009}$
# 2             $0.079_{-0.0029}^{+0.0028}$
# 3                  $2.48_{-0.25}^{+0.26}$
# 4               $0.221_{-0.023}^{+0.023}$
# 5         $0.00624_{-0.00045}^{+0.00045}$
# 6                    $14.3_{-1.6}^{+2.1}$
# 7            $0.0192_{-0.0028}^{+0.0034}$
# 8                    $10.8_{-3.2}^{+5.5}$
# 9                 $87.13_{-0.66}^{+0.79}$
# 10               $0.715_{-0.12}^{+0.069}$
# 11                    $0.0_{-0.0}^{+0.0}$
# 12                    $0.0_{-0.0}^{+0.0}$
# 13                $420.0_{-29.0}^{+26.0}$
# 14                   $21.7_{-5.4}^{+6.0}$
# 15           $0.0407_{-0.0014}^{+0.0015}$
# 16           $0.0057_{-0.0015}^{+0.0018}$
# 17  $2457933.02802_{-0.00032}^{+0.00032}$
#
#                          Joint fit for K2
# 0   $2457931.89779_{-0.00031}^{+0.00032}$
# 1   $2.2604455_{-0.0000009}^{+0.0000009}$
# 2            $0.0815_{-0.0029}^{+0.0028}$
# 3                  $2.56_{-0.26}^{+0.27}$
# 4               $0.228_{-0.023}^{+0.024}$
# 5         $0.00664_{-0.00047}^{+0.00047}$
# 6                    $14.3_{-1.6}^{+2.1}$
# 7            $0.0192_{-0.0028}^{+0.0034}$
# 8                    $10.8_{-3.2}^{+5.5}$
# 9                 $87.13_{-0.66}^{+0.79}$
# 10               $0.715_{-0.12}^{+0.069}$
# 11                    $0.0_{-0.0}^{+0.0}$
# 12                    $0.0_{-0.0}^{+0.0}$
# 13                $420.0_{-29.0}^{+26.0}$
# 14                   $21.7_{-5.4}^{+6.0}$
# 15           $0.0409_{-0.0015}^{+0.0016}$
# 16           $0.0059_{-0.0016}^{+0.0019}$
# 17  $2457933.02802_{-0.00032}^{+0.00032}$

# %%
k2_100b_table
# Out:
#                                                Labels  \
# 0                      $T_{0}$ $(\mathrm{BJD_{TDB}})$
# 1                                          $P$ (days)
# 2                                           $R_p/R_*$
# 3                                    $R_p (R_\oplus)$
# 4                                         $R_p (R_J)$
# 5                                            $\delta$
# 6                                             $a/R_*$
# 7                                            $a$ (AU)
# 8   $\rho_{\mathrm{*,transit}}$ ($\mathrm{g/cm^{3}}$)
# 9                                    $i$ $(^{\circ})$
# 10                                                $b$
# 11                                                $e$
# 12                              $\omega$ ($^{\circ}$)
# 13                              $T_{\mathrm{eq}}$ (K)
# 14                                 $S$ ($S_{\oplus}$)
# 15                                    $T_{14}$ (days)
# 16                                      $\tau$ (days)
# 17                     $T_{S}$ $(\mathrm{BJD_{TDB}})$
#
#                              Description  \
# 0                       Transit Midpoint
# 1                         Orbital period
# 2                           Radius ratio
# 3                          Planet radius
# 4                          Planet radius
# 5                          Transit depth
# 6              Normalized orbital radius
# 7                        Semi-major axis
# 8                        Density of star
# 9                    Transit inclination
# 10                      Impact parameter
# 11                          Eccentricity
# 12                Argument of periastron
# 13  Equilibrium temp. (assuming $a=0.3$)
# 14                       Insolation Flux
# 15                      Transit duration
# 16               Ingress/egress duration
# 17             Time of secondary eclipse
#
#                                        K2  \
# 0    $2457140.7194_{-0.00029}^{+0.00029}$
# 1        $1.673911_{-0.00001}^{+0.00001}$
# 2         $0.02625_{-0.00011}^{+0.00011}$
# 3                  $3.41_{-0.14}^{+0.14}$
# 4               $0.304_{-0.013}^{+0.013}$
# 5      $0.000689_{-0.000005}^{+0.000006}$
# 6                $8.181_{-0.15}^{+0.093}$
# 7            $0.0452_{-0.0020}^{+0.0020}$
# 8                   $3.7_{-0.20}^{+0.13}$
# 9                 $88.98_{-0.69}^{+0.69}$
# 10              $0.146_{-0.098}^{+0.094}$
# 11                    $0.0_{-0.0}^{+0.0}$
# 12                    $0.0_{-0.0}^{+0.0}$
# 13               $1060.0_{-17.0}^{+17.0}$
# 14                $877.0_{-55.0}^{+58.0}$
# 15        $0.06627_{-0.00037}^{+0.00036}$
# 16       $0.001739_{-0.00004}^{+0.00007}$
# 17  $2457141.55635_{-0.00029}^{+0.00029}$
#
#                                    Ground  \
# 0   $2457828.69233_{-0.00049}^{+0.00066}$
# 1        $1.673906_{-0.00005}^{+0.00005}$
# 2         $0.02867_{-0.00085}^{+0.00083}$
# 3                  $3.72_{-0.19}^{+0.19}$
# 4               $0.332_{-0.017}^{+0.017}$
# 5        $0.000822_{-0.00005}^{+0.00005}$
# 6                  $7.34_{-0.65}^{+0.38}$
# 7            $0.0403_{-0.0035}^{+0.0029}$
# 8                  $2.67_{-0.65}^{+0.43}$
# 9                    $87.4_{-1.8}^{+1.7}$
# 10                 $0.33_{-0.22}^{+0.18}$
# 11                    $0.0_{-0.0}^{+0.0}$
# 12                    $0.0_{-0.0}^{+0.0}$
# 13               $1121.0_{-34.0}^{+52.0}$
# 14             $1090.0_{-130.0}^{+220.0}$
# 15           $0.0711_{-0.0013}^{+0.0011}$
# 16        $0.00222_{-0.00023}^{+0.00051}$
# 17  $2457829.52928_{-0.00049}^{+0.00066}$
#
#                      Joint fit for Ground  \
# 0   $2457828.69347_{-0.00037}^{+0.00040}$
# 1     $1.6739024_{-0.000001}^{+0.000001}$
# 2         $0.02865_{-0.00088}^{+0.00091}$
# 3                  $3.72_{-0.19}^{+0.20}$
# 4               $0.332_{-0.017}^{+0.018}$
# 5        $0.000821_{-0.00005}^{+0.00005}$
# 6                  $7.69_{-0.85}^{+0.48}$
# 7            $0.0422_{-0.0045}^{+0.0033}$
# 8                  $3.07_{-0.91}^{+0.61}$
# 9                    $87.3_{-2.0}^{+1.8}$
# 10                 $0.36_{-0.24}^{+0.20}$
# 11                    $0.0_{-0.0}^{+0.0}$
# 12                    $0.0_{-0.0}^{+0.0}$
# 13               $1094.0_{-36.0}^{+65.0}$
# 14              $990.0_{-120.0}^{+260.0}$
# 15        $0.06706_{-0.00047}^{+0.00061}$
# 16        $0.00214_{-0.00026}^{+0.00063}$
# 17  $2457829.53042_{-0.00037}^{+0.00040}$
#
#                          Joint fit for K2
# 0   $2457828.69347_{-0.00037}^{+0.00040}$
# 1     $1.6739024_{-0.000001}^{+0.000001}$
# 2         $0.02651_{-0.00031}^{+0.00064}$
# 3                  $3.45_{-0.15}^{+0.16}$
# 4               $0.308_{-0.014}^{+0.014}$
# 5        $0.000703_{-0.00002}^{+0.00003}$
# 6                  $7.69_{-0.85}^{+0.48}$
# 7            $0.0422_{-0.0045}^{+0.0033}$
# 8                  $3.07_{-0.91}^{+0.61}$
# 9                    $87.3_{-2.0}^{+1.8}$
# 10                 $0.36_{-0.24}^{+0.20}$
# 11                    $0.0_{-0.0}^{+0.0}$
# 12                    $0.0_{-0.0}^{+0.0}$
# 13               $1094.0_{-36.0}^{+65.0}$
# 14              $990.0_{-120.0}^{+260.0}$
# 15         $0.0669_{-0.00046}^{+0.00058}$
# 16        $0.00199_{-0.00025}^{+0.00060}$
# 17  $2457829.53042_{-0.00037}^{+0.00040}$

# %%
# Convert the K2-28b parameter table to LaTex 
print(k2_28b_table.to_latex(escape=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} &                                             Labels &                           Description &                                     K2 &                                 Ground &                   Joint fit for Ground &                       Joint fit for K2 \\
# \midrule
# 0  &                     $T_{0}$ $(\mathrm{BJD_{TDB}})$ &                      Transit Midpoint &  $2456977.98986_{-0.00027}^{+0.00026}$ &  $2457931.89781_{-0.00033}^{+0.00033}$ &  $2457931.89779_{-0.00031}^{+0.00032}$ &  $2457931.89779_{-0.00031}^{+0.00032}$ \\
# 1  &                                         $P$ (days) &                        Orbital period &       $2.260443_{-0.00002}^{+0.00002}$ &          $2.26044_{-0.0001}^{+0.0001}$ &  $2.2604455_{-0.0000009}^{+0.0000009}$ &  $2.2604455_{-0.0000009}^{+0.0000009}$ \\
# 2  &                                          $R_p/R_*$ &                          Radius ratio &           $0.0763_{-0.0027}^{+0.0056}$ &           $0.0785_{-0.0030}^{+0.0029}$ &            $0.079_{-0.0029}^{+0.0028}$ &           $0.0815_{-0.0029}^{+0.0028}$ \\
# 3  &                                   $R_p (R_\oplus)$ &                         Planet radius &                 $2.42_{-0.25}^{+0.27}$ &                 $2.47_{-0.26}^{+0.27}$ &                 $2.48_{-0.25}^{+0.26}$ &                 $2.56_{-0.26}^{+0.27}$ \\
# 4  &                                        $R_p (R_J)$ &                         Planet radius &              $0.216_{-0.023}^{+0.025}$ &               $0.22_{-0.023}^{+0.024}$ &              $0.221_{-0.023}^{+0.023}$ &              $0.228_{-0.023}^{+0.024}$ \\
# 5  &                                           $\delta$ &                         Transit depth &        $0.00583_{-0.00040}^{+0.00089}$ &        $0.00617_{-0.00046}^{+0.00047}$ &        $0.00624_{-0.00045}^{+0.00045}$ &        $0.00664_{-0.00047}^{+0.00047}$ \\
# 6  &                                            $a/R_*$ &             Normalized orbital radius &                   $16.9_{-3.8}^{+2.7}$ &                   $14.1_{-1.7}^{+2.2}$ &                   $14.3_{-1.6}^{+2.1}$ &                   $14.3_{-1.6}^{+2.1}$ \\
# 7  &                                           $a$ (AU) &                       Semi-major axis &           $0.0222_{-0.0050}^{+0.0044}$ &           $0.0188_{-0.0030}^{+0.0036}$ &           $0.0192_{-0.0028}^{+0.0034}$ &           $0.0192_{-0.0028}^{+0.0034}$ \\
# 8  &  $\rho_{\mathrm{*,transit}}$ ($\mathrm{g/cm^{3}}$) &                       Density of star &                  $17.9_{-9.6}^{+10.0}$ &                   $10.3_{-3.4}^{+5.7}$ &                   $10.8_{-3.2}^{+5.5}$ &                   $10.8_{-3.2}^{+5.5}$ \\
# 9  &                                   $i$ $(^{\circ})$ &                   Transit inclination &                   $88.2_{-1.5}^{+1.3}$ &                $87.11_{-0.75}^{+0.85}$ &                $87.13_{-0.66}^{+0.79}$ &                $87.13_{-0.66}^{+0.79}$ \\
# 10 &                                                $b$ &                      Impact parameter &                 $0.54_{-0.34}^{+0.22}$ &               $0.709_{-0.13}^{+0.075}$ &               $0.715_{-0.12}^{+0.069}$ &               $0.715_{-0.12}^{+0.069}$ \\
# 11 &                                                $e$ &                          Eccentricity &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ \\
# 12 &                              $\omega$ ($^{\circ}$) &                Argument of periastron &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ \\
# 13 &                              $T_{\mathrm{eq}}$ (K) &  Equilibrium temp. (assuming $a=0.3$) &                $387.0_{-28.0}^{+53.0}$ &                $424.0_{-31.0}^{+30.0}$ &                $420.0_{-29.0}^{+26.0}$ &                $420.0_{-29.0}^{+26.0}$ \\
# 14 &                                 $S$ ($S_{\oplus}$) &                       Insolation Flux &                  $15.6_{-4.0}^{+10.0}$ &                   $22.4_{-5.9}^{+7.2}$ &                   $21.7_{-5.4}^{+6.0}$ &                   $21.7_{-5.4}^{+6.0}$ \\
# 15 &                                    $T_{14}$ (days) &                      Transit duration &           $0.0398_{-0.0012}^{+0.0026}$ &           $0.0417_{-0.0017}^{+0.0021}$ &           $0.0407_{-0.0014}^{+0.0015}$ &           $0.0409_{-0.0015}^{+0.0016}$ \\
# 16 &                                      $\tau$ (days) &               Ingress/egress duration &           $0.0039_{-0.0011}^{+0.0032}$ &           $0.0057_{-0.0016}^{+0.0020}$ &           $0.0057_{-0.0015}^{+0.0018}$ &           $0.0059_{-0.0016}^{+0.0019}$ \\
# 17 &                     $T_{S}$ $(\mathrm{BJD_{TDB}})$ &             Time of secondary eclipse &  $2456979.12008_{-0.00026}^{+0.00025}$ &  $2457933.02803_{-0.00034}^{+0.00034}$ &  $2457933.02802_{-0.00032}^{+0.00032}$ &  $2457933.02802_{-0.00032}^{+0.00032}$ \\
# \bottomrule
# \end{tabular}

# %%
# Convert the K2-100b parameter table to LaTex
print(k2_100b_table.to_latex(escape=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} &                                             Labels &                           Description &                                     K2 &                                 Ground &                   Joint fit for Ground &                       Joint fit for K2 \\
# \midrule
# 0  &                     $T_{0}$ $(\mathrm{BJD_{TDB}})$ &                      Transit Midpoint &   $2457140.7194_{-0.00029}^{+0.00029}$ &  $2457828.69233_{-0.00049}^{+0.00066}$ &  $2457828.69347_{-0.00037}^{+0.00040}$ &  $2457828.69347_{-0.00037}^{+0.00040}$ \\
# 1  &                                         $P$ (days) &                        Orbital period &       $1.673911_{-0.00001}^{+0.00001}$ &       $1.673906_{-0.00005}^{+0.00005}$ &    $1.6739024_{-0.000001}^{+0.000001}$ &    $1.6739024_{-0.000001}^{+0.000001}$ \\
# 2  &                                          $R_p/R_*$ &                          Radius ratio &        $0.02625_{-0.00011}^{+0.00011}$ &        $0.02867_{-0.00085}^{+0.00083}$ &        $0.02865_{-0.00088}^{+0.00091}$ &        $0.02651_{-0.00031}^{+0.00064}$ \\
# 3  &                                   $R_p (R_\oplus)$ &                         Planet radius &                 $3.41_{-0.14}^{+0.14}$ &                 $3.72_{-0.19}^{+0.19}$ &                 $3.72_{-0.19}^{+0.20}$ &                 $3.45_{-0.15}^{+0.16}$ \\
# 4  &                                        $R_p (R_J)$ &                         Planet radius &              $0.304_{-0.013}^{+0.013}$ &              $0.332_{-0.017}^{+0.017}$ &              $0.332_{-0.017}^{+0.018}$ &              $0.308_{-0.014}^{+0.014}$ \\
# 5  &                                           $\delta$ &                         Transit depth &     $0.000689_{-0.000005}^{+0.000006}$ &       $0.000822_{-0.00005}^{+0.00005}$ &       $0.000821_{-0.00005}^{+0.00005}$ &       $0.000703_{-0.00002}^{+0.00003}$ \\
# 6  &                                            $a/R_*$ &             Normalized orbital radius &               $8.181_{-0.15}^{+0.093}$ &                 $7.34_{-0.65}^{+0.38}$ &                 $7.69_{-0.85}^{+0.48}$ &                 $7.69_{-0.85}^{+0.48}$ \\
# 7  &                                           $a$ (AU) &                       Semi-major axis &           $0.0452_{-0.0020}^{+0.0020}$ &           $0.0403_{-0.0035}^{+0.0029}$ &           $0.0422_{-0.0045}^{+0.0033}$ &           $0.0422_{-0.0045}^{+0.0033}$ \\
# 8  &  $\rho_{\mathrm{*,transit}}$ ($\mathrm{g/cm^{3}}$) &                       Density of star &                  $3.7_{-0.20}^{+0.13}$ &                 $2.67_{-0.65}^{+0.43}$ &                 $3.07_{-0.91}^{+0.61}$ &                 $3.07_{-0.91}^{+0.61}$ \\
# 9  &                                   $i$ $(^{\circ})$ &                   Transit inclination &                $88.98_{-0.69}^{+0.69}$ &                   $87.4_{-1.8}^{+1.7}$ &                   $87.3_{-2.0}^{+1.8}$ &                   $87.3_{-2.0}^{+1.8}$ \\
# 10 &                                                $b$ &                      Impact parameter &              $0.146_{-0.098}^{+0.094}$ &                 $0.33_{-0.22}^{+0.18}$ &                 $0.36_{-0.24}^{+0.20}$ &                 $0.36_{-0.24}^{+0.20}$ \\
# 11 &                                                $e$ &                          Eccentricity &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ \\
# 12 &                              $\omega$ ($^{\circ}$) &                Argument of periastron &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ &                    $0.0_{-0.0}^{+0.0}$ \\
# 13 &                              $T_{\mathrm{eq}}$ (K) &  Equilibrium temp. (assuming $a=0.3$) &               $1060.0_{-17.0}^{+17.0}$ &               $1121.0_{-34.0}^{+52.0}$ &               $1094.0_{-36.0}^{+65.0}$ &               $1094.0_{-36.0}^{+65.0}$ \\
# 14 &                                 $S$ ($S_{\oplus}$) &                       Insolation Flux &                $877.0_{-55.0}^{+58.0}$ &             $1090.0_{-130.0}^{+220.0}$ &              $990.0_{-120.0}^{+260.0}$ &              $990.0_{-120.0}^{+260.0}$ \\
# 15 &                                    $T_{14}$ (days) &                      Transit duration &        $0.06627_{-0.00037}^{+0.00036}$ &           $0.0711_{-0.0013}^{+0.0011}$ &        $0.06706_{-0.00047}^{+0.00061}$ &         $0.0669_{-0.00046}^{+0.00058}$ \\
# 16 &                                      $\tau$ (days) &               Ingress/egress duration &       $0.001739_{-0.00004}^{+0.00007}$ &        $0.00222_{-0.00023}^{+0.00051}$ &        $0.00214_{-0.00026}^{+0.00063}$ &        $0.00199_{-0.00025}^{+0.00060}$ \\
# 17 &                     $T_{S}$ $(\mathrm{BJD_{TDB}})$ &             Time of secondary eclipse &  $2457141.55635_{-0.00029}^{+0.00029}$ &  $2457829.52928_{-0.00049}^{+0.00066}$ &  $2457829.53042_{-0.00037}^{+0.00040}$ &  $2457829.53042_{-0.00037}^{+0.00040}$ \\
# \bottomrule
# \end{tabular}
