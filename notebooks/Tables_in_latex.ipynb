# %%
import numpy as np
import matplotlib.pyplot as plt
import sys

#sys.path.append("/Users/Sophie/git/MCcubed/")
#import MCcubed as mc3   # Add path to mc3 if necessary
plt.ion()

import pandas as pd
df_ground_k2_28b = pd.read_csv("../data/k2_28b/k2-28b_ground_for_latex_table.csv",sep=",",header=0)
df_k2_k2_28b = pd.read_csv("../data/k2_28b/k2-28b_k2_for_latex_table.csv",sep=",",header=0)
df_jointground_k2_28b=pd.read_csv("../data/k2_28b/k2-28b_jointground_for_latex_table.csv",sep=",",header=0)
df_jointk2_k2_28b=pd.read_csv("../data/k2_28b/k2-28b_jointk2_for_latex_table.csv",sep=",",header=0)

df_ground_k2_100b = pd.read_csv("../data/k2_100b/k2-100b_grounddata_for_latex_table.csv",sep=",",header=0)
df_k2_k2_100b = pd.read_csv("../data/k2_100b/k2-100b_k2data_for_latex_table.csv",sep=",",header=0)
df_jointground_k2_100b=pd.read_csv("../data/k2_100b/k2-100b_jointground_for_latex_table.csv",sep=",",header=0)
df_jointk2_k2_100b=pd.read_csv("../data/k2_100b/k2-100b_jointk2_for_latex_table.csv",sep=",",header=0)

df_ground_k2_104b = pd.read_csv("../data/k2_104b/k2-104b_ground_for_latex_table.csv",sep=",",header=0)
df_k2_k2_104b = pd.read_csv("../data/k2_104b/k2-104b_k2_for_latex_table.csv",sep=",",header=0)
df_jointground_k2_104b=pd.read_csv("../data/k2_104b/k2-104b_jointground_for_latex_table.csv",sep=",",header=0)
df_jointk2_k2_104b=pd.read_csv("../data/k2_104b/k2-104b_jointk2_for_latex_table.csv",sep=",",header=0)

# %%
k2_28b_table=pd.DataFrame({'Labels': df_ground_k2_28b['Labels'],
                            'Description':df_ground_k2_28b['Description'],
                            'K2': df_k2_k2_28b['K2'],
                            'Ground':df_ground_k2_28b['Ground'],
                            'Joint fit for Ground':df_jointground_k2_28b['Ground'],
                            'Joint fit for K2':df_jointk2_k2_28b['K2']})
k2_28b_table=k2_28b_table[['Labels','Description','K2','Ground','Joint fit for Ground','Joint fit for K2']]

k2_100b_table=pd.DataFrame({'Labels': df_ground_k2_100b['Labels'],
                            'Description':df_ground_k2_100b['Description'],
                            'K2': df_k2_k2_100b['K2'],
                            'Ground':df_ground_k2_100b['Ground'],
                            'Joint fit for Ground':df_jointground_k2_100b['Ground'],
                            'Joint fit for K2':df_jointk2_k2_100b['K2']})
k2_100b_table=k2_100b_table[['Labels','Description','K2','Ground','Joint fit for Ground','Joint fit for K2']]

k2_104b_table=pd.DataFrame({'Labels': df_ground_k2_104b['Labels'],
                            'Description':df_ground_k2_104b['Description'],
                            'K2': df_k2_k2_104b['K2'],
                            'Ground':df_ground_k2_104b['Ground'],
                            'Joint fit for Ground':df_jointground_k2_104b['Ground'],
                            'Joint fit for K2':df_jointk2_k2_104b['K2']})
k2_104b_table=k2_104b_table[['Labels','Description','K2','Ground','Joint fit for Ground','Joint fit for K2']]

# %%
k2_28b_table
#print(k2_28b_table.to_latex(escape=False))
# Out:
#                                                Labels  \
# 0                      $T_{0}$ $(\mathrm{BJD_{TDB}})$
# 1                                          $P$ (days)
# 2                                           $R_p/R_*$
# 3                                    $R_p (R_\oplus)$
# 4                                         $R_p (R_J)$
# 5                                            $\delta$
# 6                                             $a/R_*$
# 7                                            $a$ (AU)
# 8   $\rho_{\mathrm{*,transit}}$ ($\mathrm{g/cm^{3}}$)
# 9                                    $i$ $(^{\circ})$
# 10                                                $b$
# 11                                                $e$
# 12                              $\omega$ ($^{\circ}$)
# 13                              $T_{\mathrm{eq}}$ (K)
# 14                                 $S$ ($S_{\oplus}$)
# 15                                    $T_{14}$ (days)
# ...

# %%
k2_100b_table
#print(k2_100b_table.to_latex(escape=False))
# Out:
#                                                Labels  \
# 0                      $T_{0}$ $(\mathrm{BJD_{TDB}})$
# 1                                          $P$ (days)
# 2                                           $R_p/R_*$
# 3                                    $R_p (R_\oplus)$
# 4                                         $R_p (R_J)$
# 5                                            $\delta$
# 6                                             $a/R_*$
# 7                                            $a$ (AU)
# 8   $\rho_{\mathrm{*,transit}}$ ($\mathrm{g/cm^{3}}$)
# 9                                    $i$ $(^{\circ})$
# 10                                                $b$
# 11                                                $e$
# 12                              $\omega$ ($^{\circ}$)
# 13                              $T_{\mathrm{eq}}$ (K)
# 14                                 $S$ ($S_{\oplus}$)
# 15                                    $T_{14}$ (days)
# ...

# %%
k2_104b_table
#print(k2_104b_table.to_latex(escape=False))
# Out:
#                                                Labels  \
# 0                      $T_{0}$ $(\mathrm{BJD_{TDB}})$
# 1                                          $P$ (days)
# 2                                           $R_p/R_*$
# 3                                    $R_p (R_\oplus)$
# 4                                         $R_p (R_J)$
# 5                                            $\delta$
# 6                                             $a/R_*$
# 7                                            $a$ (AU)
# 8   $\rho_{\mathrm{*,transit}}$ ($\mathrm{g/cm^{3}}$)
# 9                                    $i$ $(^{\circ})$
# 10                                                $b$
# 11                                                $e$
# 12                              $\omega$ ($^{\circ}$)
# 13                              $T_{\mathrm{eq}}$ (K)
# 14                                 $S$ ($S_{\oplus}$)
# 15                                    $T_{14}$ (days)
# ...
